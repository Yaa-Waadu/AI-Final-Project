# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaa-Waadu/AI-Final-Project/blob/main/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import re
import glob
import collections
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GroupShuffleSplit
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# Root of dataset each with per-class subfolders
DATASET_ROOT = "/content/drive/MyDrive/asl_dataset/ASL_Gestures_36_Classes"

# my demo set
DEMO_DIR = "/content/drive/MyDrive/asl_dataset/asl_training_images"

IMG_SIZE = (64, 64)
BATCH_SIZE = 32
LETTERS = list("abcdefghijklmnopqrstuvwxyz")
NUM_CLASSES = len(LETTERS)

FILENAME_PATTERN = re.compile(r'(hand\d+)_([a-z])_(bot|top|left|right|dif)_seg_(\d+)_cropped\.jpeg$')
# Out:
# Mounted at /content/drive
